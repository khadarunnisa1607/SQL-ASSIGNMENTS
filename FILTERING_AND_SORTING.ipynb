# %% [markdown]
# Q1) Show employees working in either the ‘IT’ or ‘HR’ departments.
#
# ![Screenshot 2026-03-24 220056.png](data:image/png;base64,...)

# %% [markdown]
# Q2): Retrieve employees whose department is in ‘Sales’, ‘IT’, or ‘Finance’.
#
# ![Screenshot 2026-03-24 220553.png](data:image/png;base64,...)

# %% [markdown]
# Question 3 : Display employees whose salary is between ₹50,000 and ₹70,000.
#
# ![Screenshot 2026-03-24 220934.png](data:image/png;base64,...)

# %% [markdown]
# Question 4 : List employees whose names start with the letter ‘A’.
#
# ![Screenshot 2026-03-24 221318.png](data:image/png;base64,...)

# %% [markdown]
# Question 5 : Find employees whose names contain the substring ‘an’.
# ![Screenshot 2026-03-24 221443.png](data:image/png;base64,...)

# %% [markdown]
# Question 6 : Show employees who are from ‘Delhi’ or ‘Mumbai’ and earn more than ₹55,000.
# ![Screenshot 2026-03-24 221443.png](data:image/png;base64,...)

# %% [markdown]
# Question 7 : Display all employees except those from the ‘HR’ department.
# ![Screenshot 2026-03-24 221953.png](data:image/png;base64,...)

# %% [markdown]
#  Q8)Get all employees hired between 2019 and 2022, ordered by HireDate (oldest first).
#  ![Screenshot 2026-03-24 222325.png](data:image/png;base64,...)
