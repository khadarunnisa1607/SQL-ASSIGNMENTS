# %% [markdown]
# 1)Q1. Create a New Database and  Table for Employees
#
# Task: Create a new database named company_db and Create a table named employees with the following
# columns:
# ![Screenshot 2026-03-24 205404.png](data:image/png;base64,...)

# %% [markdown]
# Q2)![Screenshot 2026-03-24 211705.png](data:image/png;base64,...)
#
#
#
#
#
#
#
#
# ![Screenshot 2026-03-24 210327.png](data:image/png;base64,...)

# %% [markdown]
# Q3)Q3. Display All Employee Records Sorted by Salary (Lowest to Highest)
#
# Hint: Use the clause on the salary column.
#
# ![Screenshot 2026-03-24 210538.png](data:image/png;base64,...)

# %% [markdown]
# Q4. Show Employees Sorted by Department (A–Z) and Salary (High → Low)
# ![Screenshot 2026-03-24 210704.png](data:image/png;base64,...)

# %% [markdown]
# Q5. List All Employees in the IT Department, Ordered by Hire Date (Newest First)
#
# ![Screenshot 2026-03-24 211051.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2026-03-24 213459.png](data:image/png;base64,...)![Screenshot 2026-03-24 212609.png](data:image/png;base64,...)

# %% [markdown]
# Q7) Display All Sales Records Sorted by Amount (Highest → Lowest).
# ![Screenshot 2026-03-24 213642.png](data:image/png;base64,...)

# %% [markdown]
# Q8. Show All Sales Made by Customer “Aditi”
#
# ![Screenshot 2026-03-24 213834.png](data:image/png;base64,...)

# %% [markdown]
# Q9. What is the Difference Between a Primary Key and a Foreign Key?
# ![Screenshot 2026-03-24 213959.png](data:image/png;base64,...)

# %% [markdown]
# Q10. What Are Constraints in SQL and Why Are They Used?
# ans:
# constraints in MYSQL are rules appplied to table columns to control what data can be stored.
# They are used to keep the data accurate, valid, and reliable.
